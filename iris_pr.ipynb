# %%
import webbrowser
import pandas as pd
from pandas import Series,DataFrame

# %%
website="https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records"

# %%
webbrowser.open_new_tab(website)
# Out:
# True

# %%
nfl=pd.read_clipboard()
nfl
# Out:
# C:\Users\SOUVIK_ROY\Anaconda3\lib\site-packages\pandas\io\clipboards.py:63: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_table(StringIO(text), sep=sep, **kwargs)
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
# 5     6        Minnesota Vikings  470   390    10  0.546              1961
#
#   Total Games   Division
# 0         882   NFC East
# 1       1,336  NFC North
# 2       1,370  NFC North
# 3         800   AFC East
# 4         884   AFC East
# 5         870  NFC North

# %%
nfl.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Total Games', 'Division'],
#       dtype='object')

# %%
nfl["Team"]
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2              Chicago Bears
# 3             Miami Dolphins
# 4    New England Patriots[b]
# 5          Minnesota Vikings
# Name: Team, dtype: object

# %%
DataFrame(nfl,columns=['Team','Won','Pct.'])
# Out:
#                       Team  Won   Pct.
# 0           Dallas Cowboys  502  0.573
# 1        Green Bay Packers  737  0.565
# 2            Chicago Bears  749  0.562
# 3           Miami Dolphins  445  0.559
# 4  New England Patriots[b]  489  0.558
# 5        Minnesota Vikings  470  0.546

# %%
nfl
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
# 5     6        Minnesota Vikings  470   390    10  0.546              1961
#
#   Total Games   Division
# 0         882   NFC East
# 1       1,336  NFC North
# 2       1,370  NFC North
# 3         800   AFC East
# 4         884   AFC East
# 5         870  NFC North

# %%
nfl.tail()
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
# 5     6        Minnesota Vikings  470   390    10  0.546              1961
#
#   Total Games   Division Stadium
# 1       1,336  NFC North      ab
# 2       1,370  NFC North     NaN
# 3         800   AFC East      cd
# 4         884   AFC East     NaN
# 5         870  NFC North     NaN

# %%
nfl
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
# 5     6        Minnesota Vikings  470   390    10  0.546              1961
#
#   Total Games   Division Stadium
# 0         882   NFC East     NaN
# 1       1,336  NFC North      ab
# 2       1,370  NFC North     NaN
# 3         800   AFC East      cd
# 4         884   AFC East     NaN
# 5         870  NFC North     NaN

# %%
del nfl['Stadium']

# %%
nfl
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
# 5     6        Minnesota Vikings  470   390    10  0.546              1961
#
#   Total Games   Division
# 0         882   NFC East
# 1       1,336  NFC North
# 2       1,370  NFC North
# 3         800   AFC East
# 4         884   AFC East
# 5         870  NFC North

# %%
nfl['Stadium']='abcd'
nfl
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
# 5     6        Minnesota Vikings  470   390    10  0.546              1961
#
#   Total Games   Division Stadium
# 0         882   NFC East    abcd
# 1       1,336  NFC North    abcd
# 2       1,370  NFC North    abcd
# 3         800   AFC East    abcd
# 4         884   AFC East    abcd
# 5         870  NFC North    abcd

# %%
nfl['Stadium']=Series(['ab','cd'],index=[1,3])

# %%
nfl
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
# 5     6        Minnesota Vikings  470   390    10  0.546              1961
#
#   Total Games   Division Stadium
# 0         882   NFC East     NaN
# 1       1,336  NFC North      ab
# 2       1,370  NFC North     NaN
# 3         800   AFC East      cd
# 4         884   AFC East     NaN
# 5         870  NFC North     NaN

# %%
DataFrame(nfl)
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1           Dallas Cowboys  502   374     6  0.573              1960
# 1     2        Green Bay Packers  737   562    37  0.565              1921
# 2     3            Chicago Bears  749   579    42  0.562              1920
# 3     4           Miami Dolphins  445   351     4  0.559              1966
# 4     5  New England Patriots[b]  489   386     9  0.558              1960
# 5     6        Minnesota Vikings  470   390    10  0.546              1961
#
#   Total Games   Division Stadium
# 0         882   NFC East     NaN
# 1       1,336  NFC North      ab
# 2       1,370  NFC North     NaN
# 3         800   AFC East      cd
# 4         884   AFC East     NaN
# 5         870  NFC North     NaN

# %%
d,'pop':[2={'city':['ab','cd'],'pop':[2]}

# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('Iris_dataset.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.countplot('Species', data = data)

# %%
data.Species.value_counts().plot(kind = 'bar')

# %%
data.count()
# Out:
# Id               150
# SepalLengthCm    150
# SepalWidthCm     150
# PetalLengthCm    150
# PetalWidthCm     150
# Species          150
# dtype: int64

# %%
x = data.SepalLengthCm
y = data.Species
plt.scatter(x,y,label ='SepalLengthCm')

x = data.SepalWidthCm
y = data.Species
plt.scatter(x,y,label ='SepalWidthCm')

x = data.PetalLengthCm
y = data.Species
plt.scatter(x,y,label ='PetalLengthCm')

x = data.PetalWidthCm
y = data.Species
plt.scatter(x,y,label ='PetalWidthCm')

plt.legend(loc = 4, prop={'size':7})
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X = data.drop('Species',axis = 1)
y = data.Species

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
LR = LogisticRegression()
LR.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_predict = LR.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
accuracy_score(y_test,y_predict)
# Out:
# 1.0

# %%
confusion_matrix(y_test,y_predict)
# Out:
# array([[19,  0,  0],
#        [ 0, 15,  0],
#        [ 0,  0, 16]], dtype=int64)

# %%
print(classification_report(y_test,y_predict))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        15
#  Iris-virginica       1.00      1.00      1.00        16
#
#     avg / total       1.00      1.00      1.00        50
